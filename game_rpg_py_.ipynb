# %% [markdown]
# <a href="https://colab.research.google.com/github/zhafir-dev/zhafir2.octocat.github.io/blob/main/game_rpg_py_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Hero:
  # Constructor: Dijalankan saat Hero baru dibuat
  def __init__(self, name, hp, attack_power):
    self.name = name # Nama Hero
    self.hp = hp # Nyawa (Health Point)
    self.attack_power = attack_power # Kekuatan Serangan

  # Method untuk menampilkan info hero
  def info(self):
    print(f"Hero: {self.name} | HP: {self.hp} | Power:{self.attack_power}")

  # Method menyerang: Objek ini (self) menyerang objek lain (lawan)
  def serang(self, lawan):
    print(f"{self.name} menyerang {lawan.name}!")
    lawan.diserang(self.attack_power)

  # Method diserang: Menerima damage
  def diserang(self, damage):
    self.hp -= damage
    print(f"{self.name} terkena damage {damage}. Sisa HP:{self.hp}")

# Class Mage adalah anak dari class Hero
class Mage(Hero):
  def __init__(self, name, hp, attack_power, mana):

# Memanggil constructor milik Parent (Hero)
    super().__init__(name, hp, attack_power)
    self.mana = mana

  def info(self):
    print(f"{self.name} [Mage] | HP: {self.hp} | Mana:{self.mana}")

# Mage punya skill khusus
  def skill_electricball(self, lawan):
    if self.mana >= 20:
      print(f"{self.name} menggunakan electricball ke{lawan.name}!")
      self.mana -= 20
      lawan.diserang(self.attack_power * 2) # Damage 2x lipat
    else:
      print(f"{self.name} gagal skill! Mana tidak cukup.")

# -- Main Program --
# Membuat Object (Instansiasi)
hero1 = Hero("Layla", 500, 15)
hero2 = Hero("Zilong", 120, 20)

# Memanggil Method
hero1.info()
hero2.info()

# Tambah kode Output di akhir program
print("\n--- Pertarungan Dimulai ---")

hero1.serang(hero2) # Layla menyerang Zilong
hero2.serang(hero1) # Zilong membalas

# Display the final HP of heroes
print("\n--- Pertarungan Selesai ---")
hero1.info()
hero2.info()

# -- Main Program Baru --
print("\n--- Update Class Hero ---")
eudora = Mage("Eudora", 80, 30, 100)
balmond = Hero("Balmond", 200, 10)
eudora.info()
eudora.serang(balmond) # Serangan biasa (warisan dari Hero)
eudora.skill_electricball(balmond) # Skill khusus Mage
# Out:
# Hero: Layla | HP: 500 | Power:15
# Hero: Zilong | HP: 120 | Power:20
#
# --- Pertarungan Dimulai ---
# Layla menyerang Zilong!
# Zilong terkena damage 15. Sisa HP:105
# Zilong menyerang Layla!
# Layla terkena damage 20. Sisa HP:480
#
# --- Pertarungan Selesai ---
# Hero: Layla | HP: 480 | Power:15
# Hero: Zilong | HP: 105 | Power:20
#
# --- Update Class Hero ---
# Eudora [Mage] | HP: 80 | Mana:100
# Eudora menyerang Balmond!
# Balmond terkena damage 30. Sisa HP:170
# Eudora menggunakan electricball keBalmond!
# Balmond terkena damage 60. Sisa HP:110

# %% [markdown]
# Analisi1: Hp hero1 yaitu Layla berubah dari 100 menjadi 500

# %% [markdown]
# Analisis2: karena agar satu hero bisa berinteraksi dengan hero yang lain

# %% [markdown]
# Analisis3: Karena class mage adalah class turunan dari class hero, sehingga tidak bisa langsung mendapat atributnya.
#
# Fungsi code Super() adalah untuk menghubungkan classMage(class turunan) dengan classHero(ParentClass) untuk mendapatkan atributnya

# %%
class Hero:
  def __init__(self, nama, hp_awal):
    self.nama = nama
# Enkapsulasi: HP bersifat Private (hanya bisa diakses di dalam class ini)
    self.__hp = hp_awal
# GETTER: Cara resmi melihat HP
  def get_hp(self):
    return self.__hp
# SETTER: Cara resmi mengubah HP (dengan validasi)
  def set_hp(self, nilai_baru):
    self.__hp = nilai_baru
  def diserang(self, damage):

# Kita pakai setter/getter bahkan di dalam class sendiri agar aman
    sisa_hp = self.get_hp() - damage
    self.set_hp(sisa_hp)
    print(f"{self.nama} terkena damage {damage}. Sisa HP:{self.get_hp()}")

# -- Uji Coba --
hero1 = Hero("Layla", 100)
hero1.set_hp(-100)
# hero1.__hp = 9999 # GAGAL (Tidak akan mengubah hp asli)
# print(hero1.__hp) # ERROR (Tidak bisa dibaca langsung)
print(hero1.get_hp()) # Output: 0 (Karena dicegat oleh logika Setter)
print(f"Mencoba akses paksa: {hero1._Hero__hp}")
# Out:
# -100
# Mencoba akses paksa: -100

# %% [markdown]
# Analisis4: karena atribut hp dibuat tidak 100% private, python hanya menggunakan Name Mangling cuma untuk mengubah nama atribut,Namun, cara ini tidak dianjurkan karena melewati validasi yang sudah dibuat melalui getter dan setter.
#
# setelah diubah menjadi hero1.set_hp(-100) dan penghapusan if, eilf, dan else, hp menjadi -100. Setter sangat penting karena setter dapat digunakan untuk memastikan data tetap sesuai aturan.

# %%
from abc import ABC, abstractmethod
# 1. Interface / Abstract Class
# Ini adalah KONTRAK. Semua turunan wajib punya method di bawah ini.
class GameUnit(ABC):
    @abstractmethod

    def serang(self, target):
        pass
    @abstractmethod
    def info(self):
        pass

# 2. Implementasi pada Class Konkret
class Hero(GameUnit):
    def __init__(self, nama):
        self.nama = nama
    # Kita WAJIB membuat method serang, kalau tidak akan Error
    def serang(self, target):
        print(f"Hero {self.nama} menebas {target}!")
    def info(self):
        print(f"Saya adalah Hero: {self.nama}")

class Monster(GameUnit):
    def __init__(self, jenis):
        self.jenis = jenis
# Implementasi serang versi Monster
    def serang(self, target):
        print(f"Monster {self.jenis} menggigit {target}!")
    def info(self):
        print(f"Saya adalah Monster: {self.jenis}")

# -- Uji Coba --
# unit = GameUnit() # ERROR! Abstract class tidak bisa jadi objek.
h = Hero("Alucard")
m = Monster("Serigala")
h.info()
m.info()
# Out:
# Saya adalah Hero: Alucard
# Saya adalah Monster: Serigala

# %% [markdown]
# Analisis 5: Python tidak mengizinkan kita membuat objek dari class Hero karena Hero masih belum memenuhi semua aturan yang diwajibkan oleh abstract class GameUnit
#
# GameUnit tidak bisa dibuat menjadi objek karena merupakan abstract class yang digunakan sebagai aturan untuk class turunannya.
#
# Gunanya adalah untuk memastikan class seperti Hero dan Monster memiliki method yang wajib dibuat, seperti serang() dan info().

# %%
# Parent Class
class Hero:
  def __init__(self, nama):
    self.nama = nama
  def serang(self):
    print("Hero menyerang dengan tangan kosong.")
  # Child Class 1

class Mage(Hero):
  def serang(self):
    print(f"{self.nama} (Mage) menembakkan Bola Api! Boom!")
  # Child Class 2

class Archer(Hero):
  def tembak_panah(self):
    print(f"{self.nama} (Archer) memanah dari jauh! Jleb!")
  # Child Class 3

class Fighter(Hero):
  def serang(self):
    print(f"{self.nama} (Fighter) memukul dengan pedang! Slash!")
  # -- Penerapan Polymorphism --
  # Kita punya daftar hero campuran

class Healer(Hero):
    def serang(self):
        print(f"{self.nama} tidak menyerang, tapi menyembuhkan teman!")

pasukan = [
Mage("Eudora"),
Archer("Miya"),
Fighter("Zilong"),
Mage("Gord"),
Healer("Rafaela")
]

print("--- PERANG DIMULAI ---")
# Satu perintah loop, tapi respon berbeda-beda (Polymorphism)
for pahlawan in pasukan:
  pahlawan.serang()
# Out:
# --- PERANG DIMULAI ---
# Eudora (Mage) menembakkan Bola Api! Boom!
# Hero menyerang dengan tangan kosong.
# Zilong (Fighter) memukul dengan pedang! Slash!
# Gord (Mage) menembakkan Bola Api! Boom!
# Rafaela tidak menyerang, tapi menyembuhkan teman!

# %% [markdown]
# Analisis 6: 1. Ya, program tetap berjalan lancar walaupun kita menambahkan class Healer. Kita tidak perlu mengubah looping karena Healer juga memiliki method serang().
#
# Polymorphism memudahkan programmer menambahkan karakter baru tanpa harus mengubah kode yang sudah ada. Jadi program lebih mudah dikembangkan.
#
# Apa yang terjadi?
#
# Archer tidak menjalankan aksi memanah karena method serang() sudah diganti menjadi tembak_panah(). Saat looping memanggil serang(), yang digunakan adalah method serang() dari Hero.
#
# Mengapa nama method harus sama?
#
# Karena polymorphism menggunakan perintah yang sama untuk objek yang berbeda. Dengan nama method yang sama, setiap class bisa memberikan respon atau perilaku yang berbeda terhadap perintah tersebut.
